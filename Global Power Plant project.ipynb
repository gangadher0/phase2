# %%
# !pip install pandas --upgrade
# Out:
# Requirement already satisfied: pandas in c:\users\gdmis\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gdmis\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gdmis\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\gdmis\anaconda3\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gdmis\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\gdmis\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
df = pd.read_csv('global_power_plant_database.csv')
df
# Out:
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3         AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4         AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
# ...       ...          ...                                                ...
# 29905     ZMB       Zambia                                              Ndola
# 29906     ZMB       Zambia                                              Nkana
# 29907     ZMB       Zambia                                     Victoria Falls
# 29908     ZWE     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 29909     ZWE     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
#           gppd_idnr  capacity_mw  latitude  longitude primary_fuel  \
# 0      GEODB0040538        33.00   32.3220    65.1190        Hydro
# 1      GEODB0040541        66.00   34.5560    69.4787        Hydro
# 2      GEODB0040534       100.00   34.6410    69.7170        Hydro
# 3      GEODB0040536        11.55   34.4847    70.3633        Hydro
# 4      GEODB0040540        42.00   34.5638    69.1134          Gas
# ...             ...          ...       ...        ...          ...
# 29905    WRI1022386        50.00  -12.9667    28.6333          Oil
# 29906    WRI1022384        20.00  -12.8167    28.2000          Oil
# 29907    WRI1022380       108.00  -17.9167    25.8500        Hydro
# 29908  GEODB0040404       920.00  -18.3835    26.4700         Coal
# 29909  GEODB0003803       750.00  -16.5222    28.7619        Hydro
#
#       other_fuel1 other_fuel2  ...  \
# 0             NaN         NaN  ...
# 1             NaN         NaN  ...
# 2             NaN         NaN  ...
# 3             NaN         NaN  ...
# 4             NaN         NaN  ...
# ...           ...         ...  ...
# 29905         NaN         NaN  ...
# 29906         NaN         NaN  ...
# 29907         NaN         NaN  ...
# 29908         NaN         NaN  ...
# 29909         NaN         NaN  ...
#
#                                                      url  geolocation_source  \
# 0                     http://globalenergyobservatory.org               GEODB
# 1                     http://globalenergyobservatory.org               GEODB
# 2                     http://globalenergyobservatory.org               GEODB
# 3                     http://globalenergyobservatory.org               GEODB
# 4                     http://globalenergyobservatory.org               GEODB
# ...                                                  ...                 ...
# 29905  http://www.erb.org.zm/reports/EnergySectorRepo...        Power Africa
# 29906  http://www.erb.org.zm/reports/EnergySectorRepo...        Power Africa
# 29907  http://www.erb.org.zm/reports/EnergySectorRepo...        Power Africa
# 29908                 http://globalenergyobservatory.org               GEODB
# 29909                 http://globalenergyobservatory.org               GEODB
#
#        wepp_id year_of_capacity_data generation_gwh_2013 generation_gwh_2014  \
# 0      1009793                2017.0                 NaN                 NaN
# 1      1009795                2017.0                 NaN                 NaN
# 2      1009797                2017.0                 NaN                 NaN
# 3      1009787                2017.0                 NaN                 NaN
# 4          NaN                2017.0                 NaN                 NaN
# ...        ...                   ...                 ...                 ...
# 29905  1089529                   NaN                 NaN                 NaN
# 29906  1043097                   NaN                 NaN                 NaN
# 29907  1033763                   NaN                 NaN                 NaN
# 29908  1033856                2017.0                 NaN                 NaN
# 29909  1033857                2017.0                 NaN                 NaN
#
#       generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                     NaN                  NaN                  NaN
# 1                     NaN                  NaN                  NaN
# 2                     NaN                  NaN                  NaN
# 3                     NaN                  NaN                  NaN
# 4                     NaN                  NaN                  NaN
# ...                   ...                  ...                  ...
# 29905                 NaN                  NaN                  NaN
# 29906                 NaN                  NaN                  NaN
# 29907                 NaN                  NaN                  NaN
# 29908                 NaN                  NaN                  NaN
# 29909                 NaN                  NaN                  NaN
#
#        estimated_generation_gwh
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 29905                120.872642
# 29906                 48.349057
# 29907                702.100000
# 29908               4397.000000
# 29909               5431.000000
#
# [29910 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29910 entries, 0 to 29909
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   29910 non-null  object
#  1   country_long              29910 non-null  object
#  2   name                      29910 non-null  object
#  3   gppd_idnr                 29910 non-null  object
#  4   capacity_mw               29910 non-null  float64
#  5   latitude                  29910 non-null  float64
#  6   longitude                 29910 non-null  float64
#  7   primary_fuel              29910 non-null  object
#  8   other_fuel1               1963 non-null   object
#  9   other_fuel2               303 non-null    object
#  10  other_fuel3               104 non-null    object
#  11  commissioning_year        16303 non-null  float64
#  12  owner                     19531 non-null  object
#  13  source                    29895 non-null  object
#  14  url                       29892 non-null  object
#  15  geolocation_source        29491 non-null  object
#  16  wepp_id                   16381 non-null  object
#  17  year_of_capacity_data     13743 non-null  float64
#  18  generation_gwh_2013       6996 non-null   float64
#  19  generation_gwh_2014       7440 non-null   float64
#  20  generation_gwh_2015       8144 non-null   float64
#  21  generation_gwh_2016       8971 non-null   float64
#  22  generation_gwh_2017       9213 non-null   float64
#  23  estimated_generation_gwh  21791 non-null  float64
# dtypes: float64(11), object(13)
# memory usage: 5.5+ MB

# %%
selected_column = [
    'country',
    'country_long',
    'name',
    'capacity_mw',
    'primary_fuel',
    'other_fuel1',
    'other_fuel2',
    'other_fuel3',
    'commissioning_year',
    'year_of_capacity_data',
    'generation_gwh_2013',
    'generation_gwh_2014',
    'generation_gwh_2015',
    'generation_gwh_2016',
    'generation_gwh_2017',
    'estimated_generation_gwh'
]

# %%
len(selected_column)
# Out:
# 16

# %%
df.sample(4)
# Out:
#       country              country_long                 name   gppd_idnr  \
# 21208     USA  United States of America  CNE at Cambridge MD  USA0059842
# 2331      BRA                    Brazil           Millennium  BRA0028588
# 2639      BRA                    Brazil         Potiguar III  BRA0029556
# 8451      EST                   Estonia             Paldiski  WRI1022403
#
#        capacity_mw  latitude  longitude  fuel1 fuel2 fuel3  ...  \
# 21208        3.200   38.5158   -76.0192  Solar   NaN   NaN  ...
# 2331         4.781  -12.6940   -38.3145    Gas   NaN   NaN  ...
# 2639        66.400   -5.8688   -35.3046    Oil   NaN   NaN  ...
# 8451        45.000   59.3717    24.0808   Wind   NaN   NaN  ...
#
#                                      owner  \
# 21208  Constellation Solar Maryland II LLC
# 2331                                   NaN
# 2639                                   NaN
# 8451                         Eesti Energia
#
#                                               source  \
# 21208         U.S. Energy Information Administration
# 2331   Agência Nacional de Energia Elétrica (Brazil)
# 2639   Agência Nacional de Energia Elétrica (Brazil)
# 8451                Estonian Wind Energy Association
#
#                                                      url  \
# 21208       http://www.eia.gov/electricity/data/browser/
# 2331   http://www2.aneel.gov.br/aplicacoes/capacidade...
# 2639   http://www2.aneel.gov.br/aplicacoes/capacidade...
# 8451   http://www.tuuleenergia.ee/en/windpower-101/st...
#
#                                   geolocation_source year_of_capacity_data  \
# 21208         U.S. Energy Information Administration                2016.0
# 2331   Agência Nacional de Energia Elétrica (Brazil)                2017.0
# 2639   Agência Nacional de Energia Elétrica (Brazil)                2017.0
# 8451                Estonian Wind Energy Association                   NaN
#
#       generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 21208                 NaN                  NaN                  NaN
# 2331                  NaN                  NaN                  NaN
# 2639                  NaN                  NaN                  NaN
# 8451                  NaN                  NaN                  NaN
#
#        generation_gwh_2016  estimated_generation_gwh
# 21208                6.377                  3.687111
# 2331                   NaN                 34.345155
# 2639                   NaN                284.018054
# 8451                   NaN                 97.804966
#
# [4 rows x 22 columns]

# %%
df.describe()
# Out:
#         capacity_mw      latitude     longitude  commissioning_year  \
# count  29910.000000  29910.000000  29910.000000        16303.000000
# mean     186.294810     32.497558    -12.458680         1995.486227
# std      525.703572     23.654472     76.978265           23.525537
# min        1.000000    -77.847000   -179.977700         1896.000000
# 25%        4.774430     28.863475    -79.211275         1986.000000
# 50%       18.900000     40.071250     -3.746700         2005.000000
# 75%      100.000000     47.134575     24.931050         2012.063866
# max    22500.000000     71.292000    179.388700         2018.000000
#
#        year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# count           13743.000000          6996.000000          7440.000000
# mean             2016.860001           689.625437           664.840134
# std                 1.195205          2330.869715          2258.351290
# min              2000.000000          -947.600000          -989.619000
# 25%              2017.000000             2.167000             2.157000
# 50%              2017.000000            27.033000            23.005000
# 75%              2017.000000           250.600500           224.955250
# max              2018.000000         50834.000000         32320.917000
#
#        generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# count          8144.000000          8971.000000          9213.000000
# mean            664.270784           583.622877           579.524723
# std            2304.225386          2097.603620          2063.070235
# min            -864.428000          -768.620000          -934.944000
# 25%               2.350250             2.380500             3.202000
# 50%              22.094000            17.862000            20.462000
# 75%             238.437917           187.084835           192.567000
# max           59546.865000         32377.477000         35116.000000
#
#        estimated_generation_gwh
# count              21791.000000
# mean                 847.036474
# std                 4067.434967
# min                    0.000000
# 25%                   10.082961
# 50%                   53.417041
# 75%                  339.874490
# max               450562.692350

# %% [markdown]
# # Fule use in power plant
# # Primary Fule

# %%
main_primary_fuel = df.primary_fuel.value_counts()
main_primary_fuel
# Out:
# primary_fuel
# Hydro             7155
# Solar             5929
# Wind              5188
# Gas               3922
# Coal              2390
# Oil               2290
# Biomass           1396
# Waste             1087
# Nuclear            198
# Geothermal         189
# Storage             58
# Other               44
# Cogeneration        41
# Petcoke             13
# Wave and Tidal      10
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (12, 8)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
# Out:
# C:\Users\gdmis\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
countries_plant = df.country_long.value_counts().head(30)
countries_plant
# Out:
# country_long
# United States of America    8686
# China                       3041
# United Kingdom              2536
# Brazil                      2340
# France                      2017
# Canada                      1154
# Germany                      982
# India                        861
# Spain                        614
# Russia                       505
# Portugal                     462
# Czech Republic               457
# Australia                    429
# Japan                        329
# Norway                       306
# Chile                        254
# Mexico                       251
# Italy                        247
# Argentina                    231
# Vietnam                      220
# Poland                       189
# Finland                      185
# Indonesia                    178
# Sweden                       168
# Thailand                     168
# Switzerland                  166
# South Korea                  128
# Austria                      103
# South Africa                 101
# Philippines                  101
# Name: count, dtype: int64

# %%
sns.barplot(x = countries_plant.index, y = countries_plant)
plt.xticks(rotation = 90)
plt.title('Country Designation')
plt.ylabel('Number of Power Plant')
plt.xlabel('Countries');

# %%
main_primary_fuel = df.primary_fuel.value_counts() * 100 / df.primary_fuel.count()
main_primary_fuel
# Out:
# primary_fuel
# Hydro             23.921765
# Solar             19.822802
# Wind              17.345369
# Gas               13.112671
# Coal               7.990639
# Oil                7.656302
# Biomass            4.667335
# Waste              3.634236
# Nuclear            0.661986
# Geothermal         0.631896
# Storage            0.193915
# Other              0.147108
# Cogeneration       0.137078
# Petcoke            0.043464
# Wave and Tidal     0.033434
# Name: count, dtype: float64

# %%
sns.barplot(x = main_primary_fuel, y = main_primary_fuel.index)
plt.title('Main primary fuel')
plt.xlabel('Count (Percentages)');
plt.ylabel('Different type of power plant depands on the type of fuel uses');

# %% [markdown]
# # Capacity of generating power

# %%
countries_capacity = df.groupby('country_long')[['capacity_mw']].sum().sort_values('capacity_mw', ascending = False).head(30)
countries_capacity
# Out:
#                            capacity_mw
# country_long
# China                     1.363283e+06
# United States of America  1.193616e+06
# India                     2.886941e+05
# Russia                    2.275555e+05
# Japan                     2.116678e+05
# Brazil                    1.457885e+05
# Canada                    1.434552e+05
# France                    1.092853e+05
# Germany                   1.091628e+05
# South Korea               9.940678e+04
# United Kingdom            8.741818e+04
# Saudi Arabia              8.421855e+04
# Spain                     7.616657e+04
# Italy                     7.157396e+04
# Australia                 6.573117e+04
# Iran                      6.128810e+04
# Mexico                    5.970050e+04
# Turkey                    5.078610e+04
# South Africa              5.017230e+04
# Indonesia                 4.875142e+04
# Ukraine                   4.785400e+04
# Vietnam                   3.973409e+04
# Thailand                  3.934410e+04
# Poland                    3.790200e+04
# Taiwan                    3.709756e+04
# Egypt                     3.342400e+04
# Norway                    3.255100e+04
# Argentina                 3.240058e+04
# Venezuela                 3.109600e+04
# United Arab Emirates      2.960700e+04

# %%
sns.barplot(x = countries_capacity.index, y = countries_capacity.capacity_mw)
plt.xticks(rotation = 90)
plt.title('Countries with capacity');
